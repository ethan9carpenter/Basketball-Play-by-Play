# %%
from tempAnalysisPrep import prep
from collections import Counter
import pandas as pd
import sqlite3 as sql

# %%
conn = sql.connect("ncaa_pbp.db")
year = 2014
df = pd.read_sql("""
                    SELECT
                        EventPlayerID, EventTeamID, EventType, EventID
                    From
                        "poss_{}"
                    WHERE
                        EventType NOT LIKE "%8"
                     """.format(year), conn, index_col='EventID')
df = prep(df)

# %%
data = df[df['Count'] >= 600]
data = data.sort_values('AveragePoints', ascending=False)

# %%
#from collections import Counter
#Counter(data.reset_index()['PlayerName']).most_common()

# %%
data
# Out:
#                     AveragePoints  Count
# PlayerName
# Aj English               1.068333    600
# Doug Mcdermott           1.020279    789
# Cj Fair                  1.006173    648
# Kyle Anderson            1.002099    953
# Russ Smith               0.998549    689
# Ryan Harrow              0.996711    608
# Jerrelle Benimon         0.990755    649
# Andrew Wiggins           0.988618    615
# Deandre Kane             0.987692    650
# Lamar Patterson          0.987322    631
# Roberto Nelson           0.983257    657
# Stephen Madison          0.978723    658
# Shabazz Napier           0.972261    721
# Tj Warren                0.967933    842
# Jabari Parker            0.967742    682
# Jordan Clarkson          0.963415    656
# Cameron Bairstow         0.962559    641
# Troy Huff                0.961415    622
# Jordan Mcrae             0.957290    679
# Daniel Mullings          0.957006    628
# James Young              0.956098    615
# Cameron Payne            0.953748    627
# Chris Jones              0.951548    743
# Nick Johnson             0.948800    625
# Davon Usher              0.945904    647
# Markel Starks            0.945364    604
# Juwan Staten             0.942529    609
# Jahii Carson             0.942008    707
# Isaiah Williams          0.941667    600
# Julius Randle            0.941176    629
# ...                           ...    ...
# Terran Petteway          0.893092    608
# Qj Peterson              0.890823    632
# Anthony Ireland          0.887500    640
# Bryce Cotton             0.885375    759
# Jeremy Ingram            0.884969    652
# Shawn Glover             0.884384    666
# Jon Severe               0.883614    653
# Branden Frazier          0.882353    646
# Xavier Thames            0.881579    608
# Sidney Sanders Jr.       0.879139    604
# Brandon Young            0.874183    612
# Antoine Mason            0.873418    869
# Desmar Jackson           0.873418    632
# Dj Balentine             0.872404    674
# Malcolm Miller           0.871492    677
# Sean Kilpatrick          0.867452    679
# Kj Mcdaniels             0.867200    625
# Jelani Hewitt            0.866774    623
# Elfrid Payton            0.865022    689
# Michael Williams         0.855956    722
# Team                     0.854813   2514
# Justin Black             0.847114    641
# Zeke Upshaw              0.835277    686
# Chad Frazier             0.831715    618
# Ian Chiles               0.827231    874
# Lamont Middleton         0.825197    635
# Isiah Umipig             0.815057    611
# Aaron Bacote             0.810544    607
# Jordan Downing           0.801600    625
# Kareem Canty             0.768882    662
#
# [78 rows x 2 columns]

# %%
data.loc[['Marcus Smart', 'Andrew Wiggins']]
# Out:
#                 AveragePoints  Count
# PlayerName
# Marcus Smart         1.008489    589
# Andrew Wiggins       0.988618    615
