# %%
import pandas as pd

# %%
df = pd.read_csv('temp.csv', index_col='EventID')

df
# Out:
#          GameID  Season  DayNum  WTeamID  LTeamID  WPoints  LPoints  \
# EventID
# 52            0    2010       7     1143     1293        0        0
# 54            0    2010       7     1143     1293       10       10
#
#          ElapsedSeconds  EventTeamID  EventPlayerID   EventType  PlayerID  \
# EventID
# 52                  338         1293         602781  miss1_free    602781
# 54                  338         1293         602781   made2_lay    602781
#
#         PlayerName  TeamID   TeamName
# EventID
# 52       Ivan Aska    1293  Murray St
# 54       Ivan Aska    1293  Murray St

# %%
df1 = pd.read_csv('temp1.csv', index_col='EventID')
df1
# Out:
#          ElapsedSeconds  EventTeamID  GameID  EventPlayerID  Season  DayNum  \
# EventID
# 54                  338         1293       0         602781    2010       7
#
#          WTeamID  LTeamID  WPoints  LPoints  EventType  PlayerID PlayerName  \
# EventID
# 54          1143     1293       10       10  made2_lay    602781  Ivan Aska
#
#          TeamID   TeamName  madeFT  attFT
# EventID
# 54         1293  Murray St       0      1
